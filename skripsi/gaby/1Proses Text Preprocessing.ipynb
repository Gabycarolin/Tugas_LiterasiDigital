# %%
# !pip install mapply

# %% [markdown]
# # Import Library

# %%
# Import Library Pendukung untuk Proses Text Pre-processing
import re
import pandas as pd
import numpy as np
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import mapply

# %%
mapply.init(
    n_workers=-1,
    chunk_size=100,
    max_chunks_per_worker=8,
    progressbar=False
)

# %% [markdown]
# # Import Corpus

# %%
# Import File Corpus Normalisasi
with open("./normalisasi.txt") as f:
    normalisasi = f.read().splitlines()
# normalisasi

# %%
# Import File Corpus Stopword
with open("./stopword.txt") as f:
    stopwords = f.read().splitlines()
# stopword

# %% [markdown]
# # Import Data Latih Learning Journal

# %%
# Import Data Latih
df = pd.read_csv("datalatih.csv",sep=',')
df
# Out:
#             Timestamp                       Email  \
# 0  5/25/2021 22:52:46        nevarida24@gmail.com
# 1  5/25/2021 19:18:31         shandy318@gmail.com
# 2  5/25/2021 18:20:46       meilinniafa@gmail.com
# 3  5/25/2021 18:21:03   adynugrahaputra@gmail.com
# 4  5/25/2021 14:37:22      refandika888@gmail.com
# 5  5/25/2021 20:01:52     dimasfajrul24@gmail.com
# 6  5/25/2021 18:02:01    Ryanhartadi999@gmail.com
# 7  5/25/2021 20:48:38       dekos301199@gmail.com
# 8  5/25/2021 21:02:43  titikrosanti2000@gmail.com
# 9  5/25/2021 21:17:07   Nafislestamanta@gmail.com
#
#                         Nama Mahasiswa        NIM  Semester Golongan  \
# 0       Nevarida sindyka diliana putri  E41180466         6        A
# 1             Shandy Maulana Yudantiar  E41180463         6        A
# 2              Meilinnia Fortuna Astri  E41180229         6        A
# 3           Ady Nugraha Putra Ramadhan  E41180123         6        A
# 4  Refandra Bramandika Miftahul Akhyar  E41180449         6        A
# 5                   dimas Fajrul Falah  e41180458         6        A
# 6                         Ryan Hartadi  E41180111         6        A
# 7                    Denny eko satrijo  E41180325         6        A
# 8                        Titik Rosanti  E41180124         6        A
# 9          Nafis Hibatullah Lestamanta  E41180163         6        A
#
#                            Matakuliah  Minggu Ke Tanggal Perkuliahan  \
# 0  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 1  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 2  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 3  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 4  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 5  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 6  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 7  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 8  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 9  Organisasi dan Arsitektur Komputer          9           5/25/2021
#
#                                               Topik  \
# 0                                   Overview materi
# 1                                   Overview Materi
# 2                                   Overview Materi
# 3                                   Overview Materi
# 4                                          Overview
# 5  Review video Inside your computer - Bettina Bair
# 6                                   Overview Materi
# 7                                   Materi Overview
# 8        Apa itu organisasi komputer dan arsitektur
# 9                              Inside Your Computer
#
#                       Apa yang sudah anda Pelajari ?
# 0  Dalam perkuliahan hari ini pak angga memberika...
# 1  Dalam pertemuan ini mengingat kembali definisi...
# 2  Komputer berasal dari kata Computare yang arti...
# 3  Pada Pertemuan Hari ini saya membuat suatu rin...
# 4  Saya mempelajari cara kerja perintah yang masu...
# 5  dari video yang telah saya lihat dan amati, sa...
# 6  Cara komputer bekerja ketika kita klik mouse m...
# 7  Organisasi personal personal komputer   & Arsi...
# 8  Organisasi komputer dan Arsitektur komputer me...
# 9  Organisasi komputer serta Arsitektur komputer ...

# %% [markdown]
# # Buat Fungsi Text Preprocessing

# %%
# Cleaning
def _cleaning(term):
    # Hapus pencatuman username    
    _term = re.sub(r"@[\w]*", "", term)
    # Hapus hyperlink  
    _term =  re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL', _term)
    # Hapus special character    
    _term = re.sub(r"[()\"#/@;:<>{}*`'+=~|.!?,]", "", _term)
    _term = re.sub('[^a-zA-Zа-яА-Я1-9]+', ' ', _term)
    # Remove multiple space 
    _term = re.sub("\s\s+", " ", _term)
    # Remove emoticons
    _regrex_pattern = re.compile(pattern="["
                                    u"\U0001F600-\U0001F64F"  # emoticons
                                    u"\U0001F300-\U0001F5FF"  # symbols
                                    u"\U0001F680-\U0001F6FF"  # transport & map symbols
                                    u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                                    "]+", flags=re.UNICODE)
    return re.sub(_regrex_pattern, "", _term)
    
# Casefolding (lowercase)
def _casefolding(term):
    _term = term.lower()
    return _term

# Tokenizing (token)
def _tokenizing(term):
    if not isinstance(term, str): return
    return term.split()

# Normalisasi (Ubah kata alay atau typo)
def _normalisasi(term):
    temp = term
    for w in normalisasi:
        try:
            w_ = w.split(',')
            if term.index(w_[0]):
                temp = [w_[1] if word == w_[0] else word for word in term]
        except:
            continue
    return temp

# Stopword (hapus kata tidak penting (bag of words))
def _stopword(term):
    temp = [w for w in term if not w in stopwords]
    return temp

# Stemming (pengambilan kata dasar)
def _stemming(terms):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    tweet = stemmer.stem(" ".join(terms))
    return tweet.split()

# Proses Text Pre-processing
def normalization(term): 
    cleaning = _cleaning(str(term))
    casefolding = _casefolding(cleaning)
    tokenizing = _tokenizing(casefolding)
    normalisasi = _normalisasi(tokenizing)
    stopword = _stopword(normalisasi)
    stemming = _stemming(stopword)
   
    return [cleaning, casefolding, tokenizing, normalisasi, stopword, stemming]

def callback(x):
    cleaning, casefolding, tokenizing, normalisasi, stopword, stemming = normalization(x)
    return pd.Series({'cleaning': cleaning, 'casefolding': casefolding, 'tokenizing': tokenizing,'normalisasi':normalisasi,'stopword': stopword,'stemming': stemming, 'cleaned': " ".join(stemming)})

# %% [markdown]
# # Data Training

# %%
df['Apa yang sudah anda Pelajari ?']
# Out:
# 0    Dalam perkuliahan hari ini pak angga memberika...
# 1    Dalam pertemuan ini mengingat kembali definisi...
# 2    Komputer berasal dari kata Computare yang arti...
# 3    Pada Pertemuan Hari ini saya membuat suatu rin...
# 4    Saya mempelajari cara kerja perintah yang masu...
# 5    dari video yang telah saya lihat dan amati, sa...
# 6    Cara komputer bekerja ketika kita klik mouse m...
# 7    Organisasi personal personal komputer   & Arsi...
# 8    Organisasi komputer dan Arsitektur komputer me...
# 9    Organisasi komputer serta Arsitektur komputer ...
# Name: Apa yang sudah anda Pelajari ?, dtype: object

# %%
normalization = df['Apa yang sudah anda Pelajari ?'].mapply(callback)
df = pd.concat([df,normalization], axis=1, join='inner')

# %%
df['stemming']
df
# Out:
#             Timestamp                       Email  \
# 0  5/25/2021 22:52:46        nevarida24@gmail.com
# 1  5/25/2021 19:18:31         shandy318@gmail.com
# 2  5/25/2021 18:20:46       meilinniafa@gmail.com
# 3  5/25/2021 18:21:03   adynugrahaputra@gmail.com
# 4  5/25/2021 14:37:22      refandika888@gmail.com
# 5  5/25/2021 20:01:52     dimasfajrul24@gmail.com
# 6  5/25/2021 18:02:01    Ryanhartadi999@gmail.com
# 7  5/25/2021 20:48:38       dekos301199@gmail.com
# 8  5/25/2021 21:02:43  titikrosanti2000@gmail.com
# 9  5/25/2021 21:17:07   Nafislestamanta@gmail.com
#
#                         Nama Mahasiswa        NIM  Semester Golongan  \
# 0       Nevarida sindyka diliana putri  E41180466         6        A
# 1             Shandy Maulana Yudantiar  E41180463         6        A
# 2              Meilinnia Fortuna Astri  E41180229         6        A
# 3           Ady Nugraha Putra Ramadhan  E41180123         6        A
# 4  Refandra Bramandika Miftahul Akhyar  E41180449         6        A
# 5                   dimas Fajrul Falah  e41180458         6        A
# 6                         Ryan Hartadi  E41180111         6        A
# 7                    Denny eko satrijo  E41180325         6        A
# 8                        Titik Rosanti  E41180124         6        A
# 9          Nafis Hibatullah Lestamanta  E41180163         6        A
#
#                            Matakuliah  Minggu Ke Tanggal Perkuliahan  \
# 0  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 1  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 2  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 3  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 4  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 5  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 6  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 7  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 8  Organisasi dan Arsitektur Komputer          9           5/25/2021
# 9  Organisasi dan Arsitektur Komputer          9           5/25/2021
#
#                                               Topik  \
# 0                                   Overview materi
# 1                                   Overview Materi
# 2                                   Overview Materi
# 3                                   Overview Materi
# 4                                          Overview
# 5  Review video Inside your computer - Bettina Bair
# 6                                   Overview Materi
# 7                                   Materi Overview
# 8        Apa itu organisasi komputer dan arsitektur
# 9                              Inside Your Computer
#
#                       Apa yang sudah anda Pelajari ?  \
# 0  Dalam perkuliahan hari ini pak angga memberika...
# 1  Dalam pertemuan ini mengingat kembali definisi...
# 2  Komputer berasal dari kata Computare yang arti...
# 3  Pada Pertemuan Hari ini saya membuat suatu rin...
# 4  Saya mempelajari cara kerja perintah yang masu...
# 5  dari video yang telah saya lihat dan amati, sa...
# 6  Cara komputer bekerja ketika kita klik mouse m...
# 7  Organisasi personal personal komputer   & Arsi...
# 8  Organisasi komputer dan Arsitektur komputer me...
# 9  Organisasi komputer serta Arsitektur komputer ...
#
#                                             cleaning  \
# 0  Dalam perkuliahan hari ini pak angga memberika...
# 1  Dalam pertemuan ini mengingat kembali definisi...
# 2  Komputer berasal dari kata Computare yang arti...
# 3  Pada Pertemuan Hari ini saya membuat suatu rin...
# 4  Saya mempelajari cara kerja perintah yang masu...
# 5  dari video yang telah saya lihat dan amati say...
# 6  Cara komputer bekerja ketika kita klik mouse m...
# 7  Organisasi personal personal komputer Arsitekt...
# 8  Organisasi komputer dan Arsitektur komputer me...
# 9  Organisasi komputer serta Arsitektur komputer ...
#
#                                          casefolding  \
# 0  dalam perkuliahan hari ini pak angga memberika...
# 1  dalam pertemuan ini mengingat kembali definisi...
# 2  komputer berasal dari kata computare yang arti...
# 3  pada pertemuan hari ini saya membuat suatu rin...
# 4  saya mempelajari cara kerja perintah yang masu...
# 5  dari video yang telah saya lihat dan amati say...
# 6  cara komputer bekerja ketika kita klik mouse m...
# 7  organisasi personal personal komputer arsitekt...
# 8  organisasi komputer dan arsitektur komputer me...
# 9  organisasi komputer serta arsitektur komputer ...
#
#                                           tokenizing  \
# 0  [dalam, perkuliahan, hari, ini, pak, angga, me...
# 1  [dalam, pertemuan, ini, mengingat, kembali, de...
# 2  [komputer, berasal, dari, kata, computare, yan...
# 3  [pada, pertemuan, hari, ini, saya, membuat, su...
# 4  [saya, mempelajari, cara, kerja, perintah, yan...
# 5  [dari, video, yang, telah, saya, lihat, dan, a...
# 6  [cara, komputer, bekerja, ketika, kita, klik, ...
# 7  [organisasi, personal, personal, komputer, ars...
# 8  [organisasi, komputer, dan, arsitektur, komput...
# 9  [organisasi, komputer, serta, arsitektur, komp...
#
#                                          normalisasi  \
# 0  [dalam, perkuliahan, hari, ini, pak, angga, me...
# 1  [dalam, pertemuan, ini, mengingat, kembali, de...
# 2  [komputer, berasal, dari, kata, computare, yan...
# 3  [pada, pertemuan, hari, ini, saya, membuat, su...
# 4  [saya, mempelajari, cara, kerja, perintah, yan...
# 5  [dari, video, yang, telah, saya, lihat, dan, a...
# 6  [cara, komputer, bekerja, ketika, kita, klik, ...
# 7  [organisasi, personal, personal, komputer, ars...
# 8  [organisasi, komputer, dan, arsitektur, komput...
# 9  [organisasi, komputer, serta, arsitektur, komp...
#
#                                             stopword  \
# 0  [perkuliahan, angga, tugas, mengamati, merevie...
# 1  [pertemuan, definisi, infrastruktur, organisas...
# 2  [komputer, berasal, computare, menghitung, bah...
# 3  [pertemuan, ringkasan, kesimpulan, definisi, k...
# 4  [mempelajari, kerja, perintah, masuk, kedalam,...
# 5  [video, lihat, amati, mempelajari, kerja, peri...
# 6  [komputer, klik, mouse, mengirimkan, pesan, ko...
# 7  [organisasi, personal, personal, komputer, ars...
# 8  [organisasi, komputer, arsitektur, komputer, p...
# 9  [organisasi, komputer, arsitektur, komputer, p...
#
#                                             stemming  \
# 0  [kuliah, angga, tugas, amat, mereview, resume,...
# 1  [temu, definisi, infrastruktur, organisasi, ko...
# 2  [komputer, asal, computare, hitung, bahasa, ko...
# 3  [temu, ringkas, simpul, definisi, komputer, ar...
# 4  [ajar, kerja, perintah, masuk, dalam, komputer...
# 5  [video, lihat, amat, ajar, kerja, perintah, ma...
# 6  [komputer, klik, mouse, kirim, pesan, komputer...
# 7  [organisasi, personal, personal, komputer, ars...
# 8  [organisasi, komputer, arsitektur, komputer, p...
# 9  [organisasi, komputer, arsitektur, komputer, p...
#
#                                              cleaned
# 0  kuliah angga tugas amat mereview resume vidio ...
# 1  temu definisi infrastruktur organisasi kompute...
# 2  komputer asal computare hitung bahasa komputer...
# 3  temu ringkas simpul definisi komputer arsitekt...
# 4  ajar kerja perintah masuk dalam komputer prose...
# 5  video lihat amat ajar kerja perintah masuk dal...
# 6  komputer klik mouse kirim pesan komputer tanga...
# 7  organisasi personal personal komputer arsitekt...
# 8  organisasi komputer arsitektur komputer paham ...
# 9  organisasi komputer arsitektur komputer periha...

# %% [markdown]
# # Export File CSV

# %%
# Export Hasil Text Pre-processing
filename = "Hasil_PreProcessing.csv"
df.to_csv(filename, index=False)
